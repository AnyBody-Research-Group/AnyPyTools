# %% [markdown]
# # Batch processing

# %% [markdown]
# The approach to batch processing depends on the structure of the anybody model. A commonly used strategy is a single anyscript main file. The main file is then loaded with different define statements to set the trial name, subject id or other parameters. This strategy for batch processing is outlined on the [anyscript.org wiki page](http://wiki.anyscript.org/index.php/Running_several_files_as_batch).
#
# Another strategy is to have a separate main file for each trial. These individual main-files hold all trial-specific data and include a base model that is common to all trials and subjects. The approach makes it much easier to work with mocap models that have many subject or hundreds of trials.
#
# The following shows how to batch process models where each trials is its own main file.

# %% [markdown]
# ## Model with many main files

# %% [markdown]
# This <path:Tutorial_files/BatchProcessExample.zip>) illustrates the concept of a single model with many main files. The model is based on the Arm2D demo from the AnyBody tutorials. The main files are located in subfolders (`model1`-`model9`).

# %%
# !dir /d  "Tutorial_files/BatchProcess"
# Out:
#  Volume in drive D is Dev
#  Volume Serial Number is C4A6-BC0D
#
#  Directory of D:\repos\AnyPyTools\docs\user-guide\Tutorial_files\BatchProcess
#
# [.]               [model1]          [model5]          [model9]
# [..]              [model2]          [model6]          [Output]
# batchprocess.py   [model3]          [model7]          RunExample.bat
# Demo.Arm2D.any    [model4]          [model8]
#                3 File(s)         11'358 bytes
#               12 Dir(s)  59'120'091'136 bytes free

# %%
# !dir /s /b "main.any"
# Out:
# D:\repos\AnyPyTools\docs\user-guide\Tutorial_files\BatchProcess\model1\main.any
# D:\repos\AnyPyTools\docs\user-guide\Tutorial_files\BatchProcess\model2\main.any
# D:\repos\AnyPyTools\docs\user-guide\Tutorial_files\BatchProcess\model3\main.any
# D:\repos\AnyPyTools\docs\user-guide\Tutorial_files\BatchProcess\model4\main.any
# D:\repos\AnyPyTools\docs\user-guide\Tutorial_files\BatchProcess\model5\main.any
# D:\repos\AnyPyTools\docs\user-guide\Tutorial_files\BatchProcess\model6\main.any
# D:\repos\AnyPyTools\docs\user-guide\Tutorial_files\BatchProcess\model7\main.any
# D:\repos\AnyPyTools\docs\user-guide\Tutorial_files\BatchProcess\model8\main.any
# D:\repos\AnyPyTools\docs\user-guide\Tutorial_files\BatchProcess\model9\main.any

# %% [markdown]
# Each of main files `main.any` has it own set of parameters, and they all include the same common fiile `Demo.Arm2D.any`.

# %%
from anypytools import AnyPyProcess
from anypytools.macro_commands import Load, RunOperation

folderlist = ["Tutorial_files/BatchProcess"]
app = AnyPyProcess(num_processes = 3)
macrolist = [
    Load("main.any"),
    RunOperation("Main.ArmModelStudy.InverseDynamics")
]

app.start_macro(macrolist, folderlist, search_subdirs= "model[1-9].*main.any" );
# Out:
# Output()
# Completed: 9
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
